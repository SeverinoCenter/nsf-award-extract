# %%
import os
import xml.etree.ElementTree as ET

# Define the path to the XML file
file_path = "/Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/000C130.xml"  

# Function to recursively print the structure of the XML
def print_xml_structure(elem, level=0):
    indent = "  " * level
    print(f"{indent}Tag: {elem.tag}, Attributes: {elem.attrib}")
    for child in elem:
        print_xml_structure(child, level + 1)

# Function to parse the XML and print its structure
def study_xml_structure(file_path):
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()
        print("Root Element:", root.tag)
        print("Structure:")
        print_xml_structure(root)
    except ET.ParseError as e:
        print(f"Error parsing {file_path}: {e}")

# Study the structure of the single XML file
study_xml_structure(file_path)
# Out:
# Root Element: rootTag
# Structure:
# Tag: rootTag, Attributes: {}
#   Tag: Award, Attributes: {}
#     Tag: AwardTitle, Attributes: {}
#     Tag: AwardEffectiveDate, Attributes: {}
#     Tag: AwardExpirationDate, Attributes: {}
#     Tag: AwardAmount, Attributes: {}
#     Tag: AwardInstrument, Attributes: {}
#       Tag: Code, Attributes: {}
#       Tag: Value, Attributes: {}
#     Tag: Organization, Attributes: {}
#       Tag: Code, Attributes: {}
#       Tag: Directorate, Attributes: {}
#         Tag: Abbreviation, Attributes: {}
#         Tag: Code, Attributes: {}
#         Tag: LongName, Attributes: {}
#       Tag: Division, Attributes: {}
#         Tag: Code, Attributes: {}
#         Tag: Abbreviation, Attributes: {}
#         Tag: LongName, Attributes: {}
#     Tag: ProgramOfficer, Attributes: {}
#       Tag: SignBlockName, Attributes: {}
#     Tag: PropsalInformation, Attributes: {}
#       Tag: ID, Attributes: {}
#     Tag: AbstractNarration, Attributes: {}
#     Tag: MinAmdLetterDate, Attributes: {}
#     Tag: MaxAmdLetterDate, Attributes: {}
#     Tag: IsHistoricalAward, Attributes: {}
#     Tag: ARRAAmount, Attributes: {}
#     Tag: Institution, Attributes: {}
#       Tag: Name, Attributes: {}
#       Tag: CityName, Attributes: {}
#       Tag: StateCode, Attributes: {}
#       Tag: ZipCode, Attributes: {}
#       Tag: PhoneNumber, Attributes: {}
#       Tag: EmailAddress, Attributes: {}
#       Tag: StreetAddress, Attributes: {}
#       Tag: CountryCode, Attributes: {}
#       Tag: CountryName, Attributes: {}
#       Tag: StateName, Attributes: {}
#       Tag: CountryFlag, Attributes: {}
#     Tag: AwardAmountRangeCategory, Attributes: {}
#     Tag: AwardExpirationDateEpoch, Attributes: {}
#     Tag: MinAmdLetterDateEpoch, Attributes: {}
#     Tag: MaxAmdLetterDateEpoch, Attributes: {}
#     Tag: AwardEffectiveDateEpoch, Attributes: {}
#     Tag: DREREFERENCE, Attributes: {}
#     Tag: AwardID, Attributes: {}

# %%
import pandas as pd

# Define the directory containing the extracted XML files
base_dir = "/Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new"  # Change this to your directory path

# Function to parse XML and extract relevant data
def parse_xml(file_path):
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()

        # Extract data based on the XML structure provided
        data = {
            "AwardTitle": root.findtext('.//Award/AwardTitle', default=""),
            "AwardEffectiveDate": root.findtext('.//Award/AwardEffectiveDate', default=""),
            "AwardExpirationDate": root.findtext('.//Award/AwardExpirationDate', default=""),
            "AwardAmount": root.findtext('.//Award/AwardAmount', default=""),
            "AwardInstrumentCode": root.findtext('.//Award/AwardInstrument/Code', default=""),
            "AwardInstrumentValue": root.findtext('.//Award/AwardInstrument/Value', default=""),
            "OrganizationCode": root.findtext('.//Award/Organization/Code', default=""),
            "DirectorateAbbreviation": root.findtext('.//Award/Organization/Directorate/Abbreviation', default=""),
            "DirectorateCode": root.findtext('.//Award/Organization/Directorate/Code', default=""),
            "DirectorateLongName": root.findtext('.//Award/Organization/Directorate/LongName', default=""),
            "DivisionCode": root.findtext('.//Award/Organization/Division/Code', default=""),
            "DivisionAbbreviation": root.findtext('.//Award/Organization/Division/Abbreviation', default=""),
            "DivisionLongName": root.findtext('.//Award/Organization/Division/LongName', default=""),
            "ProgramOfficerSignBlockName": root.findtext('.//Award/ProgramOfficer/SignBlockName', default=""),
            "PropsalInformationID": root.findtext('.//Award/PropsalInformation/ID', default=""),
            "AbstractNarration": root.findtext('.//Award/AbstractNarration', default=""),
            "MinAmdLetterDate": root.findtext('.//Award/MinAmdLetterDate', default=""),
            "MaxAmdLetterDate": root.findtext('.//Award/MaxAmdLetterDate', default=""),
            "IsHistoricalAward": root.findtext('.//Award/IsHistoricalAward', default=""),
            "ARRAAmount": root.findtext('.//Award/ARRAAmount', default=""),
            "InstitutionName": root.findtext('.//Award/Institution/Name', default=""),
            "InstitutionCityName": root.findtext('.//Award/Institution/CityName', default=""),
            "InstitutionStateCode": root.findtext('.//Award/Institution/StateCode', default=""),
            "InstitutionZipCode": root.findtext('.//Award/Institution/ZipCode', default=""),
            "InstitutionPhoneNumber": root.findtext('.//Award/Institution/PhoneNumber', default=""),
            "InstitutionEmailAddress": root.findtext('.//Award/Institution/EmailAddress', default=""),
            "InstitutionStreetAddress": root.findtext('.//Award/Institution/StreetAddress', default=""),
            "InstitutionCountryCode": root.findtext('.//Award/Institution/CountryCode', default=""),
            "InstitutionCountryName": root.findtext('.//Award/Institution/CountryName', default=""),
            "InstitutionStateName": root.findtext('.//Award/Institution/StateName', default=""),
            "InstitutionCountryFlag": root.findtext('.//Award/Institution/CountryFlag', default=""),
            "AwardAmountRangeCategory": root.findtext('.//Award/AwardAmountRangeCategory', default=""),
            "AwardExpirationDateEpoch": root.findtext('.//Award/AwardExpirationDateEpoch', default=""),
            "MinAmdLetterDateEpoch": root.findtext('.//Award/MinAmdLetterDateEpoch', default=""),
            "MaxAmdLetterDateEpoch": root.findtext('.//Award/MaxAmdLetterDateEpoch', default=""),
            "AwardEffectiveDateEpoch": root.findtext('.//Award/AwardEffectiveDateEpoch', default=""),
            "DREREFERENCE": root.findtext('.//Award/DREREFERENCE', default=""),
            "AwardID": root.findtext('.//Award/AwardID', default=""),
        }
        return data
    except ET.ParseError as e:
        print(f"Error parsing {file_path}: {e}")
        return None

# List to hold all parsed data
all_data = []
successful_files = 0
unsuccessful_files = 0

# Traverse through each subfolder in the base directory
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".xml"):
            file_path = os.path.join(root, file)
            data = parse_xml(file_path)
            if data:  # Only append if data is not None
                all_data.append(data)
                successful_files += 1
            else:
                unsuccessful_files += 1

# Create a DataFrame from the collected data
df = pd.DataFrame(all_data)

# Output the DataFrame to CSV and Pickle files
df.to_csv("combined_data_extracted.csv", index=False)
#df.to_pickle("combined_data.pkl")

# Display the DataFrame and the counts of successful and unsuccessful parses
print(df.head())
print(f"Total successful files: {successful_files}")
print(f"Total unsuccessful files: {unsuccessful_files}")
# Out:
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0834451.xml: no element found: line 138, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1066456.xml: no element found: line 119, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1028076.xml: no element found: line 226, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/9318513.xml: not well-formed (invalid token): line 61, column 28
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1028510.xml: no element found: line 130, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0506732.xml: no element found: line 141, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1038058.xml: no element found: line 111, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1147930.xml: no element found: line 115, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0848615.xml: no element found: line 107, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/8711837.xml: not well-formed (invalid token): line 29, column 531
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/7508378.xml: no element found: line 84, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1127340.xml: no element found: line 103, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0833162.xml: no element found: line 131, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1117597.xml: no element found: line 103, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/9815486.xml: not well-formed (invalid token): line 61, column 26
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0342388.xml: no element found: line 152, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0909203.xml: no element found: line 123, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0722887.xml: no element found: line 161, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1201835.xml: no element found: line 157, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/8716860.xml: not well-formed (invalid token): line 29, column 840
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1022648.xml: no element found: line 99, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0443803.xml: no element found: line 157, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/8521253.xml: not well-formed (invalid token): line 61, column 30
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/8710142.xml: not well-formed (invalid token): line 29, column 386
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0507295.xml: no element found: line 153, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0435393.xml: no element found: line 140, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0810982.xml: no element found: line 123, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/9315882.xml: no element found: line 39, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/1116081.xml: no element found: line 103, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0803440.xml: no element found: line 122, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0831791.xml: no element found: line 169, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/9314569.xml: no element found: line 92, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0826158.xml: no element found: line 135, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0098579.xml: no element found: line 125, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/9214257.xml: not well-formed (invalid token): line 29, column 1553
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0651627.xml: no element found: line 139, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0231051.xml: no element found: line 109, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/49100422C0020.xml: not well-formed (invalid token): line 52, column 10
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0833126.xml: no element found: line 97, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0225630.xml: no element found: line 185, column 0
# Error parsing /Users/mine/Documents/Projects/Research_Summer/NSF_Grant/NSF_Downloads_July082024/Data/xmls_new/0840444.xml: no element found: line 163, column 0
#                                           AwardTitle AwardEffectiveDate  \
# 0  1978 Science Faculty Professional Development ...         05/08/1978
# 1  CAREER:  Coalition Formation Among Self-Intere...         06/01/2001
# 2  Collaborative Research:  An ultra-high resolut...         09/01/2008
# 3     Computer Research Equipment (Computer Science)         07/01/1983
# 4  Acquisition of Computer Research Equipment (Co...         08/01/1984
#
#   AwardExpirationDate AwardAmount AwardInstrumentCode AwardInstrumentValue  \
# 0          09/30/1981       24600                           Standard Grant
# 1          05/31/2003      177502                         Continuing Grant
# 2          08/31/2011      284095                           Standard Grant
# 3          06/30/1985       50000                           Standard Grant
# 4          07/31/1985       26036                           Standard Grant
#
#   OrganizationCode DirectorateAbbreviation DirectorateCode  \
# 0         05060000                     CSE
# 1         05020000                     CSE
# 2         06040200                     GEO
# 3         05010005                     CSE
# 4         05010005
#
#                         DirectorateLongName  ... InstitutionCountryName  \
# 0  Direct For Computer & Info Scie & Enginr  ...          United States
# 1  Direct For Computer & Info Scie & Enginr  ...          United States
# 2               Directorate For Geosciences  ...          United States
# 3  Direct For Computer & Info Scie & Enginr  ...          United States
# 4  Direct For Computer & Info Scie & Enginr  ...          United States
#
#   InstitutionStateName InstitutionCountryFlag AwardAmountRangeCategory  \
# 0             Virginia
# 1         Pennsylvania
# 2             Michigan
# 3             New York
# 4        Massachusetts
#
#   AwardExpirationDateEpoch MinAmdLetterDateEpoch MaxAmdLetterDateEpoch  \
# 0
# 1
# 2
# 3
# 4
#
#   AwardEffectiveDateEpoch DREREFERENCE  AwardID
# 0                                       7819160
# 1                                       0234693
# 2                                       0752093
# 3                                       8304600
# 4                                       8405037
#
# [5 rows x 38 columns]
# Total successful files: 629905
# Total unsuccessful files: 41
