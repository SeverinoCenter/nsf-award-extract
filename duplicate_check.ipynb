# %%
# Import required packages everytime
import pandas as pd
import numpy as np 
pd.options.mode.chained_assignment = None  # default='warn'
import warnings
warnings.filterwarnings("ignore")
#set pythong so shows all columns
pd.set_option('display.max_columns', None)

# %%
#import Path
from pathlib import Path
import os
#path=Path('/Users/jasonkuruzovich/Library/CloudStorage/Box-Box/Documents/0_research/eship_vitor/I_CORPS/data/2024_617/NSF-Download')
#list all files in path and assign to list ourfiles
#ourfiles = os.listdir(path)

# %%
df=pd.read_csv('../Data/merged_dataframe_api_15July24.csv')
#drop first column from df
df=df.drop(df.columns[0], axis=1)
#trim th ewhitespace from the id field using lambda function
df['id'] = df['id'].apply(lambda x: str(x).strip())

# %%
df.head()
# Out:
#                                         abstractText agency  awardAgencyCode  \
# 0  Under the direction of Dr. Paul Kiparsky, Ms. ...    NSF           4900.0
# 1  The Analytical and Surface Chemistry (ASC) Pro...    NSF           4900.0
# 2  Funds are provided to continue the operation o...    NSF           4900.0
# 3  A request is made to fund additional and back-...    NSF           4900.0
# 4  The Analytical and Surface Chemistry (ASC) Pro...    NSF           4900.0
#
#                                              awardee  \
# 0              THE LELAND STANFORD JUNIOR UNIVERSITY
# 1                     TRUSTEES OF INDIANA UNIVERSITY
# 2  THE TRUSTEES OF COLUMBIA UNIVERSITY IN THE CIT...
# 3  THE TRUSTEES OF COLUMBIA UNIVERSITY IN THE CIT...
# 4                                UNIVERSITY OF MIAMI
#
#               awardeeAddress   awardeeCity awardeeCountryCode  \
# 0      450 JANE STANFORD WAY      STANFORD                 US
# 1          107 S INDIANA AVE   BLOOMINGTON                 US
# 2             615 W 131ST ST      NEW YORK                 US
# 3             615 W 131ST ST      NEW YORK                 US
# 4  1320 S DIXIE HWY STE 1200  CORAL GABLES                 US
#
#   awardeeDistrictCode                             awardeeName  \
# 0                CA16                     Stanford University
# 1                IN09                      Indiana University
# 2                NY13                     Columbia University
# 3                NY13                     Columbia University
# 4                FL27  University of Miami School of Medicine
#
#   awardeeStateCode awardeeZipCode cfdaNumber        date  estimatedTotalAmt  \
# 0               CA      943052004     47.075  05/27/2003            11975.0
# 1               IN      474057000     47.049  01/10/2008           595000.0
# 2               NY      100277922      47.05  06/15/2010           758998.0
# 3               NY      100277922      47.05  05/25/2011            22230.0
# 4               FL      331462926     47.049  02/18/2011           376087.0
#
#       expDate  fundAgencyCode                 fundProgramName  \
# 0  05/31/2006          4900.0                     Linguistics
# 1  03/31/2011          4900.0  ANALYTICAL SEPARATIONS & MEAS.
# 2  11/30/2013          4900.0   Marine Geology and Geophysics
# 3  05/31/2012          4900.0   OCEANOGRAPHIC INSTRUMENTATION
# 4  02/28/2013          4900.0  ANALYTICAL SEPARATIONS & MEAS.
#
#    fundsObligatedAmt       id         pdPIName                perfAddress  \
# 0              11975   318478    Paul Kiparsky      450 JANE STANFORD WAY
# 1             595000   748648        Sapna Deo          107 S INDIANA AVE
# 2             758998   962010  Maureen E Raymo                      Rt 9W
# 3              22230  1113045   Sean M Higgins                      Rt 9W
# 4             376087  1118356        Sapna Deo  1320 S DIXIE HWY STE 1200
#
#        perfCity perfCountryCode perfDistrictCode  \
# 0      STANFORD              US             CA16
# 1   BLOOMINGTON              US             IN09
# 2     Palisades              US             NY17
# 3     Palisades              US             NY17
# 4  CORAL GABLES              US             FL27
#
#                                         perfLocation perfStateCode  \
# 0                                Stanford University            CA
# 1                                 Indiana University            IN
# 2  Columbia University Lamont Doherty Earth Obser...            NY
# 3  Columbia University Lamont Doherty Earth Obser...            NY
# 4             University of Miami School of Medicine            FL
#
#   perfZipCode                     piEmail piFirstName piLastName poEmail  \
# 0   943052004  kiparsky@csli.stanford.edu        Paul   Kiparsky     NaN
# 1   474057000          sdeo@med.miami.edu       Sapna        Deo     NaN
# 2       10964  jmcmanus@ldeo.columbia.edu       Jerry    McManus     NaN
# 3       10964      sean@ldeo.columbia.edu        Sean    Higgins     NaN
# 4   331462926          sdeo@med.miami.edu       Sapna        Deo     NaN
#
#             poName  poPhone   startDate  \
# 0      Joan Maling      NaN  06/15/2003
# 1  Zeev Rosenzweig      NaN  03/01/2008
# 2     Bilal U. Haq      NaN  06/15/2010
# 3      James Holik      NaN  06/01/2011
# 4  Zeev Rosenzweig      NaN  10/01/2010
#
#                                                title         transType  \
# 0  Doctoral Dissertation Research:  Language Chan...    Standard Grant
# 1  CAREER:  Homogenous, Rapid, and Highly Sensiti...  Continuing Grant
# 2  The LDEO Deep-Sea Repository and the Curating ...  Continuing Grant
# 3                 Oceanographic Instrumentation 2011    Standard Grant
# 4  CAREER:  Homogenous, Rapid, and Highly Sensiti...  Continuing Grant
#
#                               primaryProgram  \
# 0                                        NaN
# 1  01001011DB NSF RESEARCH & RELATED ACTIVIT
# 2  01001213DB NSF RESEARCH & RELATED ACTIVIT
# 3  01001112DB NSF RESEARCH & RELATED ACTIVIT
# 4  01001011DB NSF RESEARCH & RELATED ACTIVIT
#
#                                  publicationResearch            coPDPI  \
# 0                                                NaN               NaN
# 1  Analytical and Bioanalytical Chemistry~2009~39...               NaN
# 2  Earth and Planetary Science Letters~2010~300~A...    William B Ryan
# 3                                                NaN  David S Goldberg
# 4  Biosensors and Bioelectronics~2011~~M. Kumar, ...               NaN
#
#   piMiddeInitial                              projectOutComesReport
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2              F  THE LAMONT-DOHERTY CORE REPOSITORY (http://www...
# 3              M   These funds were used to purchase an equipmen...
# 4            NaN   Detection of ribonucleic acids (RNAs) (riboso...

# %%
#remove duplicates from df
df2 = df.drop_duplicates()
df2['id_hash'] = df2['id'].apply(lambda x: hash(x))
#move 'id to the first column of the dataframe df2
cols = list(df2.columns)
cols.insert(0, cols.pop(cols.index('id_hash')))
cols.insert(0, cols.pop(cols.index('id')))
df2.sort_values(by='id_hash', inplace=True)
df2 = df2[cols]
#drop duplicates by id_hash

#show duplicates by id_hash
duplicates=df2[df2.duplicated(subset='id_hash', keep=False)]
duplicates
# Out:
#              id              id_hash  \
# 213676  2203231 -9222131406980666168
# 71977   2203231 -9222131406980666168
# 211     1156549 -9221792916394610082
# 100988  1156549 -9221792916394610082
# 202448  2103480 -9221491356849043784
# ...         ...                  ...
# 66980   2137264  9219036200508496321
# 98654   1062943  9219863353196736664
# 164     1062943  9219863353196736664
# 538326  1360987  9220256737003473312
# 312473  1360987  9220256737003473312
#
#                                              abstractText agency  \
# 213676  The Agency in Chemical Engineering Experiments...    NSF
# 71977   The Agency in Chemical Engineering Experiments...    NSF
# 211     Intellectual Merit<br/>This proposed three-yea...    NSF
# 100988  Intellectual Merit<br/>This proposed three-yea...    NSF
# 202448  Historically, synchronous generators, invented...    NSF
# ...                                                   ...    ...
# 66980   The pharmaceutical sector in America is a majo...    NSF
# 98654   This three year REU Site program at the Univer...    NSF
# 164     This three year REU Site program at the Univer...    NSF
# 538326  This project aims to create new pathways for n...    NSF
# 312473  This project aims to create new pathways for n...    NaN
#
#         awardAgencyCode                                 awardee  \
# 213676           4900.0                MONTANA STATE UNIVERSITY
# 71977            4900.0                MONTANA STATE UNIVERSITY
# 211              4900.0                 KANSAS STATE UNIVERSITY
# 100988           4900.0                 KANSAS STATE UNIVERSITY
# 202448           4900.0             UNIVERSITY OF SOUTH FLORIDA
# ...                 ...                                     ...
# 66980            4900.0  REGENTS OF THE UNIVERSITY OF MINNESOTA
# 98654            4900.0                  UNIVERSITY OF ILLINOIS
# 164              4900.0                  UNIVERSITY OF ILLINOIS
# 538326           4900.0   UNIVERSITY OF NEW HAVEN, INCORPORATED
# 312473           4900.0   UNIVERSITY OF NEW HAVEN, INCORPORATED
#
#                       awardeeAddress  awardeeCity awardeeCountryCode  \
# 213676              216 MONTANA HALL      BOZEMAN                 US
# 71977               216 MONTANA HALL      BOZEMAN                 US
# 211              1601 VATTIER STREET    MANHATTAN                 US
# 100988           1601 VATTIER STREET    MANHATTAN                 US
# 202448             4202 E FOWLER AVE        TAMPA                 US
# ...                              ...          ...                ...
# 66980                  200 OAK ST SE  MINNEAPOLIS                 US
# 98654   809 S MARSHFIELD AVE M/C 551      CHICAGO                 US
# 164     809 S MARSHFIELD AVE M/C 551      CHICAGO                 US
# 538326            300 BOSTON POST RD   WEST HAVEN                 US
# 312473            300 BOSTON POST RD          NaN                 US
#
#        awardeeDistrictCode                          awardeeName  \
# 213676                MT01             Montana State University
# 71977                 MT01             Montana State University
# 211                   KS01              Kansas State University
# 100988                KS01              Kansas State University
# 202448                FL15          University of South Florida
# ...                    ...                                  ...
# 66980                 MN05  University of Minnesota-Twin Cities
# 98654                 IL07    University of Illinois at Chicago
# 164                   IL07    University of Illinois at Chicago
# 538326                CT03              University of New Haven
# 312473                CT03              University of New Haven
#
#        awardeeStateCode awardeeZipCode cfdaNumber        date  \
# 213676               MT          59717     47.041  01/17/2023
# 71977                MT          59717     47.041  01/17/2023
# 211                  KS      665062504     47.041  03/13/2012
# 100988               KS      665062504     47.041  03/13/2012
# 202448               FL      336205800     47.041  03/26/2021
# ...                 ...            ...        ...         ...
# 66980                MN      554552009     47.041  02/22/2022
# 98654                IL      606124305     47.041  02/23/2011
# 164                  IL      606124305     47.041  02/23/2011
# 538326               CT      065161916     47.041  12/20/2013
# 312473              NaN      065161916     47.041         NaN
#
#         estimatedTotalAmt     expDate  fundAgencyCode  \
# 213676           176899.0  01/31/2026          4900.0
# 71977            176899.0  01/31/2026          4900.0
# 211              316398.0  11/30/2015          4900.0
# 100988           316398.0  11/30/2015          4900.0
# 202448           350000.0  04/30/2025          4900.0
# ...                   ...         ...             ...
# 66980            590000.0  02/28/2027          4900.0
# 98654            353172.0  03/31/2015          4900.0
# 164              353172.0  03/31/2015          4900.0
# 538326           292145.0  05/31/2018          4900.0
# 312473           292145.0         NaN          4900.0
#
#                        fundProgramName  fundsObligatedAmt  \
# 213676     EngEd-Engineering Education             176899
# 71977      EngEd-Engineering Education             176899
# 211     EWFD-Eng Workforce Development             316398
# 100988  EWFD-Eng Workforce Development             316398
# 202448  EPCN-Energy-Power-Ctrl-Netwrks             350000
# ...                                ...                ...
# 66980   IUCRC-Indust-Univ Coop Res Ctr             354000
# 98654   EWFD-Eng Workforce Development             353172
# 164     EWFD-Eng Workforce Development             353172
# 538326     EngEd-Engineering Education             292145
# 312473     EngEd-Engineering Education             292145
#
#                         pdPIName                   perfAddress     perfCity  \
# 213676     Stephanie G Wettstein              328 MONTANA HALL      BOZEMAN
# 71977      Stephanie G Wettstein              328 MONTANA HALL      BOZEMAN
# 211                 Keith L Hohn             1005 Durland Hall    Manhattan
# 100988              Keith L Hohn             1005 Durland Hall    Manhattan
# 202448              Lingling Fan   4202 E. Fowler Ave, ENG-030        Tampa
# ...                          ...                           ...          ...
# 66980              Changquan Sun                           NaN  Minneapolis
# 98654        Christos G Takoudis  809 S MARSHFIELD AVE M/C 551      CHICAGO
# 164          Christos G Takoudis  809 S MARSHFIELD AVE M/C 551      CHICAGO
# 538326  Maria-Isabel Carnasciali          300 Boston Post Road   West Haven
# 312473  Maria-Isabel Carnasciali          300 Boston Post Road   West Haven
#
#        perfCountryCode perfDistrictCode                         perfLocation  \
# 213676              US             MT01             Montana State University
# 71977               US             MT01             Montana State University
# 211                 US              KS"              Kansas State University
# 100988              US              KS"              Kansas State University
# 202448              US             FL15          University of South Florida
# ...                ...              ...                                  ...
# 66980               US             MN05  University of Minnesota-Twin Cities
# 98654               US             IL07    University of Illinois at Chicago
# 164                 US             IL07    University of Illinois at Chicago
# 538326              US             CT03              University of New Haven
# 312473              US             CT03              University of New Haven
#
#        perfStateCode  perfZipCode                              piEmail  \
# 213676            MT    597172470  stephanie.wettstein@coe.montana.edu
# 71977             MT    597172470  stephanie.wettstein@coe.montana.edu
# 211               KS  665065102.0                   hohnkl@miamioh.edu
# 100988            KS    665065102                   hohnkl@miamioh.edu
# 202448            FL    336172008                  linglingfan@usf.edu
# ...              ...          ...                                  ...
# 66980             MN    554552070                     sunx0053@umn.edu
# 98654             IL    606124305                     takoudis@uic.edu
# 164               IL  606124305.0                     takoudis@uic.edu
# 538326            CT    065161916            mcarnasciali@newhaven.edu
# 312473            CT    065161916            mcarnasciali@newhaven.edu
#
#          piFirstName   piLastName          poEmail         poName  \
# 213676     Stephanie    Wettstein  apawley@nsf.gov   Alice Pawley
# 71977      Stephanie    Wettstein  apawley@nsf.gov   Alice Pawley
# 211            Keith         Hohn              NaN     Mary Poats
# 100988         Keith         Hohn              NaN     Mary Poats
# 202448      Lingling          Fan     akuh@nsf.gov    Anthony Kuh
# ...              ...          ...              ...            ...
# 66980      Changquan          Sun   pbalan@nsf.gov  Prakash Balan
# 98654       Christos     Takoudis              NaN     Mary Poats
# 164         Christos     Takoudis              NaN     Mary Poats
# 538326  Maria-Isabel  Carnasciali              NaN   Julie Martin
# 312473  Maria-Isabel  Carnasciali              NaN   Julie Martin
#
#              poPhone   startDate  \
# 213676  7.032927e+09  02/01/2023
# 71977   7.032927e+09  02/01/2023
# 211              NaN  03/15/2012
# 100988           NaN  03/15/2012
# 202448  7.032925e+09  05/01/2021
# ...              ...         ...
# 66980   7.032925e+09  03/01/2022
# 98654            NaN  04/01/2011
# 164              NaN  04/01/2011
# 538326           NaN  06/01/2014
# 312473           NaN  06/01/2014
#
#                                                     title         transType  \
# 213676  Collaborative Research: Research: Agency in Ch...    Standard Grant
# 71977   Collaborative Research: Research: Agency in Ch...    Standard Grant
# 211     REU Site: Earth, Wind, and Fire: Sustainable E...  Continuing Grant
# 100988  REU Site: Earth, Wind, and Fire: Sustainable E...  Continuing Grant
# 202448  Dynamic Model Identification for Inverter-Base...    Standard Grant
# ...                                                   ...               ...
# 66980   IUCRC Phase I UMN: Center for Integrated Mater...  Continuing Grant
# 98654   REU Site in Novel Advanced Materials and Proce...  Continuing Grant
# 164     REU Site in Novel Advanced Materials and Proce...  Continuing Grant
# 538326  Collaborative Research: Impacts of Prior Work ...    Standard Grant
# 312473  Collaborative Research: Impacts of Prior Work ...    Standard Grant
#
#                                        primaryProgram  \
# 213676      01002324DB NSF RESEARCH & RELATED ACTIVIT
# 71977       01002324DB NSF RESEARCH & RELATED ACTIVIT
# 211         04001415RB NSF Education & Human Resource
# 100988      04001415RB NSF Education & Human Resource
# 202448      01002122DB NSF RESEARCH & RELATED ACTIVIT
# ...                                               ...
# 66980       01002324DB NSF RESEARCH & RELATED ACTIVIT
# 98654       04001112RB NSF Education & Human Resource
# 164         04001112RB NSF Education & Human Resource
# 538326      01001415DB NSF RESEARCH & RELATED ACTIVIT
# 312473  ['01001415DB NSF RESEARCH & RELATED ACTIVIT']
#
#                                       publicationResearch             coPDPI  \
# 213676  Proceedings of the ASEE Annual Conference and ...   Jennifer R Brown
# 71977   Proceedings of the ASEE Annual Conference and ...   Jennifer R Brown
# 211     Sustainability~2014~6~Robinson, J, G. Brase, W...   Larry E Erickson
# 100988  Sustainability~2014~6~Robinson, J, G. Brase, W...   Larry E Erickson
# 202448  2022 North American Power Symposium (NAPS)~202...        Zhixin Miao
# ...                                                   ...                ...
# 66980   International Journal of Pharmaceutics~2023~64...      Nathan A Mara
# 98654   Journal of Undergraduate Research - UIC~2014~7...  Gregory M Jursich
# 164     Journal of Undergraduate Research - UIC~2014~7...  Gregory M Jursich
# 538326  Chemical Engineering Education (Special Divers...                NaN
# 312473  ['American Society of Engineering Education~20...                NaN
#
#        piMiddeInitial                              projectOutComesReport
# 213676              G                                                NaN
# 71977               G                                                NaN
# 211                 L   Forty-four undergraduate students from multip...
# 100988              L   Forty-four undergraduate students from multip...
# 202448            NaN                                                NaN
# ...               ...                                                ...
# 66980             NaN                                                NaN
# 98654               G   The goal is a stronger and diverse U.S. workf...
# 164                 G   The goal is a stronger and diverse U.S. workf...
# 538326            NaN   This work gives insights into the diversity o...
# 312473            NaN   This work gives insights into the diversity o...
#
# [18374 rows x 42 columns]

# %%
duplicates.reset_index(drop=True, inplace=True)
duplicates.to_csv('no_duplicates_api_merged.csv', index=False)

# %%
df2 = df2.drop_duplicates(subset='id_hash', keep='first')
df2.reset_index(drop=True, inplace=True)

# %%
df3 = df2.drop_duplicates(subset='id_hash', keep='first')

# %%
#print the number of unique values in each column and the total length of the dataframe
for i in df3.columns:
    #print potential keys
    if len(df3[i].unique())==len(df2):
        print(i,"is a potential key")

    #print(i, len(df2[i].unique()), len(df2))
# Out:
# id is a potential key
# id_hash is a potential key

# %%
df3.to_csv('allNSF_2024_07_15_no_duplicates.csv', index=False)

# %%
ourfiles
# Out:
# ['NSF Org_24_06_24.csv']

# %%
ourfiles = os.listdir(path/'checkfiles')
for file in ourfiles:
    
    temp=pd.read_csv(path/'checkfiles'/file)
    temp['id'] = temp['id'].apply(lambda x: str(x).strip())
    temp['id_hash'] = temp['id'].apply(lambda x: hash(x))
    #find th the number of unique idhashes in temp that are not in df3
    tempset=set(temp['id_hash'].unique())-set(df3['id_hash'].unique())
    print(len(df3['id_hash'].unique()), len(temp['id_hash'].unique()), len(tempset))
# Out:
# 188616 82738 17048

# %%
temp.loc[temp['id_hash'].isin(tempset)]
# Out:
#        Unnamed: 0                                       abstractText agency  \
# 186             6       This research concerns the generation and...    NSF
# 187             7       A mobile fluid phase forms an important c...    NSF
# 190            10          This research involves two specific pr...    NaN
# 191            11       The long term objectives of this study ar...    NSF
# 195            15       Vegetation responses to naturally- and cu...    NSF
# ...           ...                                                ...    ...
# 96200        5024  The broader impact of this Small Business Inno...    NSF
# 96201        5025  Concern over rising global temperatures makes ...    NSF
# 96202        5026  This award supports the development of collabo...    NSF
# 96203        5027  Frailty syndrome in older adults results from ...    NSF
# 96204        5028  Mesophotic Coral Reefs are deep reefs (~100-50...    NSF
#
#        awardAgencyCode                                            awardee  \
# 186             4900.0                              UNIVERSITY OF CHICAGO
# 187             4900.0                     UNIVERSITY OF WISCONSIN SYSTEM
# 190                NaN                                                NaN
# 191             4900.0       REGENTS OF THE UNIVERSITY OF CALIFORNIA, THE
# 195             4900.0  BOARD OF REGENTS OF THE NEVADA SYSTEM OF HIGHE...
# ...                ...                                                ...
# 96200           4900.0                         NITRATE ELIMINATION CO INC
# 96201           4900.0      SAN JOSE STATE UNIVERSITY RESEARCH FOUNDATION
# 96202           4900.0  KENNESAW STATE UNIVERSITY RESEARCH AND SERVICE...
# 96203           4900.0                              UNIVERSITY OF ARIZONA
# 96204           4900.0                        GORDON RESEARCH CONFERENCES
#
#                  awardeeAddress     awardeeCity awardeeCountryCode  \
# 186            5801 S ELLIS AVE         CHICAGO                 US
# 187        21 North Park Street         MADISON                 US
# 190        77 MASSACHUSETTS AVE       Cambridge                 US
# 191         1608 4TH ST STE 201        BERKELEY                 US
# 195    1664 N VIRGINIA ST # 285            RENO                 US
# ...                         ...             ...                ...
# 96200              334 HECLA ST     LAKE LINDEN                 US
# 96201         210 4TH ST 3RD FL        SAN JOSE                 US
# 96202       1000 CHASTAIN RD NW        KENNESAW                 US
# 96203     845 N PARK AVE RM 538          TUCSON                 US
# 96204       5586 POST RD UNIT 2  EAST GREENWICH                 US
#
#       awardeeDistrictCode                                        awardeeName  \
# 186                  IL01                              University of Chicago
# 187                  WI02                    University of Wisconsin-Madison
# 190                   NaN              Massachusetts Institute of Technology
# 191                  CA12                  University of California-Berkeley
# 195                  NV02  Board of Regents, NSHE, obo University of Neva...
# ...                   ...                                                ...
# 96200                MI01                   Nitrate Elimination Company, Inc
# 96201                CA18               San Jose State University Foundation
# 96202                GA11  Kennesaw State University Research and Service...
# 96203                AZ07                              University of Arizona
# 96204                RI02                        Gordon Research Conferences
#
#       awardeeStateCode awardeeZipCode cfdaNumber        date  \
# 186                 IL      606375418     47.076  06/22/1988
# 187                 WI      537151218     47.076  06/22/1988
# 190                 MA      021394301        NaN  06/22/1988
# 191                 CA      947101749     47.076  06/22/1988
# 195                 NV      895570001     47.076  06/22/1988
# ...                ...            ...        ...         ...
# 96200               MI      499451323     47.084  01/03/2023
# 96201               CA      951125569     47.050  01/11/2023
# 96202               GA      301445588     47.078  01/06/2023
# 96203               AZ          85721     47.041  01/06/2023
# 96204               RI      028183454     47.050  01/11/2023
#
#        estimatedTotalAmt     expDate  fundAgencyCode  \
# 186              69768.0  12/31/1990          4900.0
# 187              48283.0  08/31/1990          4900.0
# 190                  NaN  12/31/1989             NaN
# 191              73861.0  02/28/1990          4900.0
# 195              71514.0  01/31/1990          4900.0
# ...                  ...         ...             ...
# 96200           256000.0  06/30/2024          4900.0
# 96201           192832.0  12/31/2025          4900.0
# 96202           199921.0  12/31/2024          4900.0
# 96203           580246.0  11/30/2033          4900.0
# 96204            30000.0  06/30/2023          4900.0
#
#                       fundProgramName  fundsObligatedAmt       id  \
# 186    STELLAR ASTRONOMY & ASTROPHYSC              69768  8722796
# 187                         Tectonics              48283  8800073
# 190                         ECONOMICS             101528  8800091
# 191          SPECIAL PROGRAMS-RESERVE              73861  8723160
# 195    Geography and Spatial Sciences              71514  8722811
# ...                               ...                ...      ...
# 96200                    SBIR Phase I             256000  2208721
# 96201   Marine Geology and Geophysics             192832  2226054
# 96202      ASSP-Arctic Social Science             199921  2243860
# 96203  Disability & Rehab Engineering             461610  2236689
# 96204         BIOLOGICAL OCEANOGRAPHY              30000  2306373
#
#                 pdPIName                     perfAddress       perfCity  \
# 186      Ellen G Zweibel                             NaN            NaN
# 187     Maria L Crawford                             NaN            NaN
# 190     Maria L Crawford                             NaN            NaN
# 191       Mary B Rheuben                             NaN            NaN
# 195         Nancy Milton                             NaN            NaN
# ...                  ...                             ...            ...
# 96200   Ellen R Campbell                  217 Calumet St    Lake Linden
# 96201  Elizabeth M Walsh               210 4TH ST 3RD FL       SAN JOSE
# 96202    Thomas E Rotnem  1000 CHASTAIN RD MAILSTOP 0111       KENNESAW
# 96203    Nima Toosizadeh     1127 E. James E. Rogers Way         TUCSON
# 96204      Marc Slattery                  512 LIBERTY LN  WEST KINGSTON
#
#       perfCountryCode perfDistrictCode  \
# 186               NaN               ""
# 187               NaN               ""
# 190               NaN              NaN
# 191               NaN               ""
# 195               NaN               ""
# ...               ...              ...
# 96200              US             MI01
# 96201              US             CA18
# 96202              US             GA11
# 96203              US             AZ07
# 96204              US             RI02
#
#                                             perfLocation perfStateCode  \
# 186                                                  NaN           NaN
# 187                                                  NaN           NaN
# 190                                                  NaN           NaN
# 191                                                  NaN           NaN
# 195                                                  NaN           NaN
# ...                                                  ...           ...
# 96200                   Nitrate Elimination Company, Inc            MI
# 96201               San Jose State University Foundation            CA
# 96202  Kennesaw State University Research and Service...            GA
# 96203                              University of Arizona            AZ
# 96204                        Gordon Research Conferences            RI
#
#       perfZipCode piFirstName  piLastName           poEmail  \
# 186           NaN       Ellen     Zweibel               NaN
# 187           NaN       Maria    Crawford               NaN
# 190           NaN     Rebecca       Blank               NaN
# 191           NaN        Mary     Rheuben               NaN
# 195           NaN       Nancy      Milton               NaN
# ...           ...         ...         ...               ...
# 96200   499451303       Ellen    Campbell  epiersto@nsf.gov
# 96201   951125569   Elizabeth       Walsh  awanamak@nsf.gov
# 96202   301445588      Thomas      Rotnem    lfrink@nsf.gov
# 96203   857210020        Nima  Toosizadeh  szehnder@nsf.gov
# 96204   028921502        Marc    Slattery  dthornhi@nsf.gov
#
#                     poName       poPhone   startDate  \
# 186         Lola E. Rogers           NaN  09/01/1988
# 187         Lola E. Rogers           NaN  09/01/1988
# 190         Lola E. Rogers           NaN  09/01/1988
# 191         Lola E. Rogers           NaN  09/01/1988
# 195         Lola E. Rogers           NaN  08/01/1988
# ...                    ...           ...         ...
# 96200      Erik Pierstorff  7.032922e+09  01/15/2023
# 96201       Alan Wanamaker  7.032928e+09  01/15/2023
# 96202           Liam Frink  7.032920e+09  01/15/2023
# 96203        Steve Zehnder  7.032927e+09  01/15/2023
# 96204  Daniel J. Thornhill  7.032928e+09  01/15/2023
#
#                                                    title         transType  \
# 186    Generation and Evolution of Astrophysical Magn...    Standard Grant
# 187    Fluid Inclusion and Stable Isotope Study in Mi...    Standard Grant
# 190    Exploring Income Opportunities for Low-Income ...    Standard Grant
# 191       Synaptic Structure And Function (Neurobiology)    Standard Grant
# 195    Modeling of Mixed Pixels and Shadowing Effects...    Standard Grant
# ...                                                  ...               ...
# 96200  SBIR Phase I: Dual enzyme system to prevent fo...    Standard Grant
# 96201  Collaborative Research: The role of the Southe...    Standard Grant
# 96202  Planning: Comparing Climate Change-Related Vul...    Standard Grant
# 96203  CAREER: Frailty Assessment for Older Adults wi...  Continuing Grant
# 96204  2023 Mesophotic Coral Reef Ecosystems Gordon R...    Standard Grant
#
#                            piEmail piMiddeInitial         coPDPI  \
# 186         zweibel@astro.wisc.edu              G            NaN
# 187          mcrawfor@brynmawr.edu              L            NaN
# 190                blank@umich.edu              L            NaN
# 191            rheuben@cvm.msu.edu              B            NaN
# 195                            NaN            NaN            NaN
# ...                            ...            ...            ...
# 96200           ellenr@nitrate.com              R            NaN
# 96201     elizabeth.walsh@sjsu.edu              M            NaN
# 96202         trotnem@kennesaw.edu              E  Firooza Pavri
# 96203  nima.toosizadeh@rutgers.edu            NaN            NaN
# 96204         slattery@olemiss.edu            NaN            NaN
#
#                                   primaryProgram publicationResearch  \
# 186                                          NaN                 NaN
# 187                                          NaN                 NaN
# 190                                          NaN                 NaN
# 191                                          NaN                 NaN
# 195                                          NaN                 NaN
# ...                                          ...                 ...
# 96200  01002324DB NSF RESEARCH & RELATED ACTIVIT                 NaN
# 96201  01002324DB NSF RESEARCH & RELATED ACTIVIT                 NaN
# 96202  0100CYXXDB NSF RESEARCH & RELATED ACTIVIT                 NaN
# 96203  01002324DB NSF RESEARCH & RELATED ACTIVIT                 NaN
# 96204  01002324DB NSF RESEARCH & RELATED ACTIVIT                 NaN
#
#                                    projectOutComesReport              id_hash
# 186                                                  NaN -1566139293562031249
# 187                                                  NaN -1002419166646327740
# 190                                                  NaN  3153292079353183242
# 191                                                  NaN  7927941245650628679
# 195                                                  NaN  2909558990845769323
# ...                                                  ...                  ...
# 96200                                                NaN -7074597840647704401
# 96201                                                NaN  4280630789419017510
# 96202                                                NaN  3350664702715337187
# 96203                                                NaN  7954046494197033734
# 96204   The Mesophotic Coral Reef Ecosystems GRC was ... -5162407403299488956
#
# [20458 rows x 43 columns]

# %%
#show id=8722796 in df3
df3.loc[df3['id']=='8722796']
# Out:
# Empty DataFrame
# Columns: [id, id_hash, abstractText, agency, awardAgencyCode, awardee, awardeeAddress, awardeeCity, awardeeCountryCode, awardeeDistrictCode, awardeeName, awardeeStateCode, awardeeZipCode, cfdaNumber, date, estimatedTotalAmt, expDate, fundAgencyCode, fundProgramName, fundsObligatedAmt, pdPIName, perfAddress, perfCity, perfCountryCode, perfDistrictCode, perfLocation, perfStateCode, perfZipCode, piEmail, piFirstName, piLastName, piMiddeInitial, poEmail, poName, poPhone, startDate, title, transType, coPDPI, primaryProgram, publicationResearch, projectOutComesReport]
# Index: []
